# %%
from pathlib import Path
import shutil

# %%
dir = r"~/Desktop/glimpsify/most_info_frame_extractor"

# %%
from typing import List
from pathlib import Path


def delete_empty_directories(dir: Path) -> List[Path]:
    """
    Recursively find all empty directories and return a list of them.
    This allows you to preview what would be deleted before actually deleting.
    """
    if not dir.is_dir():
        return []

    to_delete = []

    try:
        # Get all items in the directory
        contents = list(dir.iterdir())

        # First, recursively check subdirectories
        for content in contents:
            if content.is_dir():
                result = delete_empty_directories(content)
                to_delete.extend(result)

        # After processing subdirectories, check if current directory is now empty
        # We need to check again because subdirectories might have been marked for deletion
        remaining_contents = [item for item in contents if item.is_file() or
                            (item.is_dir() and item not in to_delete)]

        if len(remaining_contents) == 0:
            to_delete.append(dir)

    except PermissionError as e:
        print(f"Permission denied accessing {dir}: {e}")
    except Exception as e:
        print(f"Error processing {dir}: {e}")

    return to_delete


def preview_and_delete_empty_directories(root_dir: Path, actually_delete: bool = False) -> List[Path]:
    """
    Find empty directories and optionally delete them.

    Args:
        root_dir: The root directory to start searching from
        actually_delete: If True, actually delete the directories. If False, just return the list.

    Returns:
        List of directories that were found empty (and deleted if actually_delete=True)
    """
    import shutil

    empty_dirs = delete_empty_directories(root_dir)

    if empty_dirs:
        print(f"Found {len(empty_dirs)} empty directories:")
        for empty_dir in empty_dirs:
            print(f"  {empty_dir}")

        if actually_delete:
            print("\nDeleting empty directories...")
            for empty_dir in empty_dirs:
                try:
                    shutil.rmtree(empty_dir)
                    print(f"  Deleted: {empty_dir}")
                except Exception as e:
                    print(f"  Failed to delete {empty_dir}: {e}")
        else:
            print("\nTo actually delete these directories, call with actually_delete=True")
    else:
        print("No empty directories found.")

    return empty_dirs


# Example usage:
if __name__ == "__main__":
    from pathlib import Path

    # Preview what would be deleted
    root_path = Path(dir)  # Change this to your target directory

    # First, just preview
    empty_dirs = preview_and_delete_empty_directories(root_path, actually_delete=False)

    # Then, if you want to actually delete:
    # empty_dirs = preview_and_delete_empty_directories(root_path, actually_delete=True)
# Out:
# No empty directories found.

# %%
to_delete = delete_empty_directories(Path("/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives"))

# %%
to_delete
# Out:
# [PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_50_python_objects_all_dirs_phash_approval_strategy_v3_pdfs'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_46_everything_except_local_videos'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_45_everything_except_local_videos_pdfs'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/uktblu_ogz_ugy'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/xweuiu_nuc_rkb'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/zirldl_szk_vmb'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/ckkajy_atz_zjb'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/gmyvcu_dpn_msc'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/gddyar_bhp_ziu'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/kuekvo_fcp_yiz'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/sgmaal_zgd_fqp'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/bqzprh_taw_ytp'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/jkpjwe_kzf_icx'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/xxmbxs_zpc_ehi'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/hripxz_ueh_bqa'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/cruilc_osq_vni'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/lhwemu_agu_zap'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/xpetji_rvj_nct'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/yrazjn_aey_aqz'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/tabwoi_utc_cyc'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/tpfibt_cjp_ybq'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/nysxop_bcq_ibz'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/hgkxep_lla_svo'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/pssllz_ldt_xrz'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/adwxvg_gdu_pdu'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/dtwoem_nzp_dhc'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/uszriv_htl_xvc'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/jgywnx_rfq_wkk'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/cyqohz_oux_imw'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/apivsf_cex_lxt'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/pajaco_fuw_brg'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/rgqydw_lhu_hhz'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/jtkszw_gyq_skr'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/ijifjf_rmq_xhm'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/xtlxph_abk_jei'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/jautph_pvi_unl'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/txxahm_ahe_mij'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/djwahz_ppw_mre'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/bsjwsj_suf_ycz'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/hhboxg_lxm_twx'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/gdvqpv_jos_apq'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/euwetu_vqf_ngu'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/icquet_rja_umj'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/kjajup_wss_vsx'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/jqvgor_syi_avv'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/oogxef_nte_cuk'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/hkyigj_dyo_xvy'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/fcxvmr_pbt_pzs'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/wqyijj_jzq_yyu'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/trlhdz_bpv_lfa'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/eupjay_oii_mrk'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/ulgywi_fbr_oyd'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/kaitxy_koc_zyt'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/wayvbl_lga_cdt'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/ufwmpg_ati_asf'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/gkoxol_eyn_njd'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/yhiddy_vjy_hnm'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/srmqde_fys_uda'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/vxcarn_lab_xyu'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/etdnlx_saj_tgy'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/dlfoyw_phq_zby'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/sdcniw_khg_iqj'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/hydixc_tri_tit'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/sktpkr_bhg_mwt'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/yrhkqu_wbb_moq'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/mfewuh_qkh_ats'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/msskhv_dmg_cxr'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/wzwvzv_ooo_olw'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/pidfog_fsa_pbn'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/kdcdle_gbe_ofd'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/jrixdt_xgr_dba'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/tgqxfv_kil_pze'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/ihdpjv_gnn_mga'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/zrkmxn_had_mxc'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/mhhqzg_eaz_yoo'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/npurai_prq_fra'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/yysaqx_fmp_ryq'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/mlvdvr_rhl_eie'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/plllkw_ldo_wmm'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/sdipnw_hka_qbk'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/nhwrqw_vyj_oce'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/gxtjwd_gmq_ohd'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/znavfo_tfc_cur'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/sosjvp_quh_kds'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/ejftjw_rkg_wtv'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/qfsezy_apl_thl'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/zlervx_noz_sam'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/jslpij_xvr_bte'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/asycxh_rfq_yay'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/aqqzpy_cvk_fkn'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/cakavo_emg_cok'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/cftulg_fdx_ftc'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/czeswe_nns_rgd'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/dlxdzc_zoz_htx'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/xdrrpx_fow_ivr'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/hjsbwd_hya_vhj'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/wdvnza_biq_dky'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/qhisdm_cmq_bhn'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/oyxwwk_qfb_ade'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/iyyoht_xed_ffa'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/ruquuc_miu_vin'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/shngtp_ylo_myn'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/cncwmr_ivc_ntn'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/jlsjyc_egl_aol'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/afsikc_cng_bqh'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/yecmvl_liu_lfz'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/pdddxw_pbo_idc'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/pmafru_iqf_zgx'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/rzcsvv_fov_fhl'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/tvtjdv_jnu_gda'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/ruweka_emf_rbo'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/qzxibg_vyv_suz'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/yaldqc_div_lzj'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/dvpret_lrj_vqt'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/ybokqs_iey_oob'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/fxddqo_vrq_pjz'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/mbgcel_hpj_lke'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/aqeiwr_wed_plh'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/mowrkl_aff_rua'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/xfzngr_gja_oee'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/dxeqwb_ufq_tqh'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/uhrpei_qqf_wbb'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/vhghaj_myk_frj'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/olaqxj_qbz_kic'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/ozygri_akl_ors'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/uxwbeg_umy_bug'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/pwlueg_uxz_qhf'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/xiietr_vdb_dsh'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/hrpnxe_swx_xyk'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/wnhdmj_ccv_tcd'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/whsuyw_qcp_hnf'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/dhlvnv_mqn_hhi'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/menozr_bxu_gat'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/htvpfe_yua_lum'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/vvywdg_rvc_gkr'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/xgsetv_xpk_yeq'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/lxwqhv_pgz_ghg'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/rskdzi_lay_fdu'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/lhopxd_ehm_uiw'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/pbfssh_xcm_yiz'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/eqcnrd_cbn_wcp'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/vtktbw_rmt_llh'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/bmqioa_qwc_mdz'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/yirczy_wbs_ijm'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/iqntxc_lro_qfx'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/oxratx_alb_pcs'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/obwxrn_cgs_yqh'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/ubqley_kbe_jlq'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/zgpqgn_qjr_tqw'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/hpmwkt_nox_fuu'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/vvjvxf_oqp_twu'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/erhbqn_akx_fgt'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/rjgctw_crb_bvp'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/meatkb_uhj_zjj'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos/wzxlvf_okz_joh'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_52_new_reference_pdfs/sosjvp_quh_tiz'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_52_new_reference_pdfs/sdcniw_khg_prq'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_52_new_reference_pdfs/adwxvg_gdu_ril'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_52_new_reference_pdfs/pdddxw_pbo_eoi'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_52_new_reference_pdfs/tvtjdv_jnu_wwc'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_52_new_reference_pdfs/mhhqzg_eaz_ojl'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_52_new_reference_pdfs/afsikc_cng_max'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_52_new_reference_pdfs/meatkb_uhj_fhy'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_52_new_reference_pdfs/lhopxd_ehm_asb'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_52_new_reference_pdfs/yhiddy_vjy_mly'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_52_new_reference_pdfs/ozygri_akl_tcb'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_52_new_reference_pdfs/djwahz_ppw_qcq'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_52_new_reference_pdfs/ihdpjv_gnn_bfg'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_52_new_reference_pdfs/cftulg_fdx_lzz'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_52_new_reference_pdfs/xgsetv_xpk_xud'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_52_new_reference_pdfs/zgpqgn_qjr_ttd'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_52_new_reference_pdfs/gmyvcu_dpn_esk'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_52_new_reference_pdfs/tabwoi_utc_dxr'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_52_new_reference_pdfs/zrkmxn_had_drc'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_52_new_reference_pdfs/ruweka_emf_uhq'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_52_new_reference_pdfs/lxwqhv_pgz_iue'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_52_new_reference_pdfs/ufwmpg_ati_eqf'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_52_new_reference_pdfs/jtkszw_gyq_cxy'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_52_new_reference_pdfs/sdipnw_hka_wvn'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_52_new_reference_pdfs/hkyigj_dyo_ida'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_52_new_reference_pdfs/bmqioa_qwc_qew'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_52_new_reference_pdfs/aqeiwr_wed_fup'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_52_new_reference_pdfs/plllkw_ldo_mla'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_52_new_reference_pdfs/dlfoyw_phq_fgg'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_52_new_reference_pdfs/vvywdg_rvc_fis'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_52_new_reference_pdfs/xiietr_vdb_ams'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_52_new_reference_pdfs/oyxwwk_qfb_xwa'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_52_new_reference_pdfs/xxmbxs_zpc_qsk'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_52_new_reference_pdfs/yysaqx_fmp_vtb'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_52_new_reference_pdfs/xtlxph_abk_qps'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_52_new_reference_pdfs/afsikc_cng_fol'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_52_new_reference_pdfs/mlvdvr_rhl_njy'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_52_new_reference_pdfs/eupjay_oii_irw'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_52_new_reference_pdfs/qzxibg_vyv_aff'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_52_new_reference_pdfs/hydixc_tri_zlj'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_52_new_reference_pdfs/srmqde_fys_moh'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_52_new_reference_pdfs/cyqohz_oux_evx'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_52_new_reference_pdfs/wayvbl_lga_hgc'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_52_new_reference_pdfs/wnhdmj_ccv_qhw'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_52_new_reference_pdfs/pssllz_ldt_yfy'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_52_new_reference_pdfs/ijifjf_rmq_knx'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_52_new_reference_pdfs/wdvnza_biq_xuz'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_52_new_reference_pdfs/ruquuc_miu_hcm'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_52_new_reference_pdfs/apivsf_cex_ckl'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_52_new_reference_pdfs/lhwemu_agu_jeq'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_52_new_reference_pdfs/uhrpei_qqf_wza'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_52_new_reference_pdfs/xpetji_rvj_vka'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_52_new_reference_pdfs/olaqxj_qbz_vkg'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_52_new_reference_pdfs/fxddqo_vrq_oae'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_52_new_reference_pdfs/txxahm_ahe_zvi'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_52_new_reference_pdfs/tpfibt_cjp_ztm'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_52_new_reference_pdfs/czeswe_nns_avp'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_52_new_reference_pdfs/cruilc_osq_wbx'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_52_new_reference_pdfs/mfewuh_qkh_yso'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_52_new_reference_pdfs/srmqde_fys_pwr'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_52_new_reference_pdfs/gxtjwd_gmq_yzq'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_52_new_reference_pdfs/vhghaj_myk_qcz'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_52_new_reference_pdfs/hhboxg_lxm_dmc'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_52_new_reference_pdfs/yecmvl_liu_vqc'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_52_new_reference_pdfs/znavfo_tfc_mve'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_52_new_reference_pdfs/oogxef_nte_nrc'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_52_new_reference_pdfs/xfzngr_gja_hlq'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_52_new_reference_pdfs/yirczy_wbs_mch'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_52_new_reference_pdfs/obwxrn_cgs_eqg'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_52_new_reference_pdfs/kdcdle_gbe_dos'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_52_new_reference_pdfs/vtktbw_rmt_sjb'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_52_new_reference_pdfs/rgqydw_lhu_mci'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_52_new_reference_pdfs/aqqzpy_cvk_ybw'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_52_new_reference_pdfs/menozr_bxu_eea'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_52_new_reference_pdfs/dxeqwb_ufq_dhh'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_52_new_reference_pdfs/htvpfe_yua_rdd'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_52_new_reference_pdfs/sktpkr_bhg_pnp'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_52_new_reference_pdfs/hrpnxe_swx_xqa'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_52_new_reference_pdfs/npurai_prq_now'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_52_new_reference_pdfs/yaldqc_div_bxl'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_52_new_reference_pdfs/fcxvmr_pbt_rlr'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_52_new_reference_pdfs/eqcnrd_cbn_jpi'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_52_new_reference_pdfs/bqzprh_taw_exp'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_52_new_reference_pdfs/sgmaal_zgd_uac'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_52_new_reference_pdfs/iqntxc_lro_bwj'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_49_phash_results_all_dirs'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_34_generated_pdfs'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_42_reference_pdfs'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_45_everything_except_local_videos/aqeiwr_zmz'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_45_everything_except_local_videos/aqeiwr_uek'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_45_everything_except_local_videos/aqeiwr_pmu'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_45_everything_except_local_videos/aqeiwr_aeo'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_45_everything_except_local_videos/aqeiwr_axv'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_45_everything_except_local_videos/aqeiwr_nsb'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_45_everything_except_local_videos/aqeiwr_tqw'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_45_everything_except_local_videos/aqeiwr_qxw'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_44_everything_except_local_videos_/whsuyw_sua'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_44_everything_except_local_videos_/whsuyw_xsu'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_44_everything_except_local_videos_/whsuyw_tei'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_44_everything_except_local_videos_/whsuyw_koh'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_44_everything_except_local_videos_/whsuyw_hzt_extracted_frames'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_44_everything_except_local_videos_/whsuyw_xtk'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_44_everything_except_local_videos_/whsuyw_alt'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_44_everything_except_local_videos_/whsuyw_yjn'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_44_everything_except_local_videos_/ufwmpg_lmd'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_44_everything_except_local_videos_/whsuyw_hzt'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_44_everything_except_local_videos_/whsuyw_fsf'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_44_everything_except_local_videos_/whsuyw_qwd'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_44_everything_except_local_videos_/whsuyw_jgr'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_44_everything_except_local_videos_/whsuyw_uij'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_44_everything_except_local_videos_/whsuyw_rll_extracted_frames'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_44_everything_except_local_videos_/whsuyw_dbi'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_44_everything_except_local_videos_/vqesbr_lem'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_44_everything_except_local_videos_/whsuyw_hin'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_44_everything_except_local_videos_/whsuyw_mno_extracted_frames'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_44_everything_except_local_videos_/pldnrz_sqc'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_44_everything_except_local_videos_/whsuyw_mno'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_44_everything_except_local_videos_/whsuyw_jgr_extracted_frames'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_44_everything_except_local_videos_/whsuyw_rll'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_50_output_all_dirs_phash_approval_strategy_pdfs'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_54_only_long_videos_pdfs'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_54_only_long_videos/xgsetv_xpk_rov'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_54_only_long_videos/pmafru_iqf_mkn'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_54_only_long_videos/aqeiwr_wed_tfp'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_54_only_long_videos/uszriv_htl_sej'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_54_only_long_videos/erhbqn_akx_slu'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_54_only_long_videos/fxddqo_vrq_wei'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_54_only_long_videos/cftulg_fdx_rii'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_54_only_long_videos/whsuyw_qcp_nen'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_54_only_long_videos/hpmwkt_nox_hlg'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_54_only_long_videos/wqyijj_jzq_vvr'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_54_only_long_videos/hrpnxe_swx_qzw'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_54_only_long_videos/mfewuh_qkh_ync'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_54_only_long_videos/hripxz_ueh_gxf'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_54_only_long_videos/npurai_prq_dss'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_54_only_long_videos/jkpjwe_kzf_qmx'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_54_only_long_videos/vxcarn_lab_nid'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_54_only_long_videos/yhiddy_vjy_dwn'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_54_only_long_videos/gddyar_bhp_pue'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_54_only_long_videos/eqcnrd_cbn_bzm'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_54_only_long_videos/tgqxfv_kil_ppc'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_54_only_long_videos/jrixdt_xgr_ktk'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_54_only_long_videos/yysaqx_fmp_aeo'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_54_only_long_videos/lhopxd_ehm_kqi'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_54_only_long_videos/wayvbl_lga_qst'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_54_only_long_videos/oogxef_nte_yqn'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_54_only_long_videos/ozygri_akl_jrx'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_54_only_long_videos/trlhdz_bpv_qjj'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_54_only_long_videos/bsjwsj_suf_xoc'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_54_only_long_videos/kaitxy_koc_onn'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_54_only_long_videos/mhhqzg_eaz_fwk'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_54_only_long_videos/obwxrn_cgs_doi'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_54_only_long_videos/pssllz_ldt_mry'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_54_only_long_videos/iyyoht_xed_agz'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_54_only_long_videos/cruilc_osq_noo'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_54_only_long_videos/hkyigj_dyo_hzt'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_54_only_long_videos/lhwemu_agu_arg'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_54_only_long_videos/vvjvxf_oqp_dyn'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_54_only_long_videos/zgpqgn_qjr_qan'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_54_only_long_videos/jtkszw_gyq_fyh'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_54_only_long_videos/uxwbeg_umy_slh'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_54_only_long_videos/srmqde_fys_cub'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_54_only_long_videos/sdcniw_khg_nis'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_54_only_long_videos/mbgcel_hpj_zum'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_54_only_long_videos/uktblu_ogz_fmh'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_54_only_long_videos/etdnlx_saj_kmd'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_54_only_long_videos/qhisdm_cmq_hks'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_54_only_long_videos/icquet_rja_ihn'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_54_only_long_videos/czeswe_nns_bgz'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_54_only_long_videos/dlfoyw_phq_wnk'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_54_only_long_videos/ufwmpg_ati_ccb'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_54_only_long_videos/cncwmr_ivc_xep'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_54_only_long_videos/jlsjyc_egl_dbx'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_54_only_long_videos/apivsf_cex_tls'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_54_only_long_videos/yecmvl_liu_sef'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_54_only_long_videos/cakavo_emg_xej'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_54_only_long_videos/wzwvzv_ooo_hgh'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_54_only_long_videos/tvtjdv_jnu_irj'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_54_only_long_videos/dlxdzc_zoz_mmq'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_54_only_long_videos/euwetu_vqf_uez'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_54_only_long_videos/qzxibg_vyv_frj'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_54_only_long_videos/zirldl_szk_nau'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_54_only_long_videos/xpetji_rvj_gwv'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_54_only_long_videos/tabwoi_utc_paw'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_54_only_long_videos/yaldqc_div_nlm'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_54_only_long_videos/rskdzi_lay_dfr'),
# ...
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_50_output_all_dirs_phash_approval_strategy/rzcsvv_fov'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_50_output_all_dirs_phash_approval_strategy/jslpij_xvr'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_50_output_all_dirs_phash_approval_strategy/jtkszw_gyq'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_50_output_all_dirs_phash_approval_strategy/znavfo_tfc'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_50_output_all_dirs_phash_approval_strategy/adwxvg_gdu'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_50_output_all_dirs_phash_approval_strategy/hripxz_ueh'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_50_output_all_dirs_phash_approval_strategy/qfsezy_apl'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_50_output_all_dirs_phash_approval_strategy/fxddqo_vrq'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_50_output_all_dirs_phash_approval_strategy/srmqde_fys'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_50_output_all_dirs_phash_approval_strategy/yirczy_wbs'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_50_output_all_dirs_phash_approval_strategy/apivsf_cex'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_50_output_all_dirs_phash_approval_strategy/ruquuc_miu'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_50_output_all_dirs_phash_approval_strategy/vvjvxf_oqp'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_50_output_all_dirs_phash_approval_strategy/asycxh_rfq'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_50_output_all_dirs_phash_approval_strategy/dhlvnv_mqn'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_50_output_all_dirs_phash_approval_strategy/qzxibg_vyv'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_50_output_all_dirs_phash_approval_strategy/bsjwsj_suf'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_50_output_all_dirs_phash_approval_strategy/czeswe_nns'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_50_output_all_dirs_phash_approval_strategy/ulgywi_fbr'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_50_output_all_dirs_phash_approval_strategy/yaldqc_div'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_50_output_all_dirs_phash_approval_strategy/gkoxol_eyn'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_50_output_all_dirs_phash_approval_strategy/zrkmxn_had'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_50_output_all_dirs_phash_approval_strategy/kuekvo_fcp'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_50_output_all_dirs_phash_approval_strategy/xxmbxs_zpc'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_50_output_all_dirs_phash_approval_strategy/pssllz_ldt'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_50_output_all_dirs_phash_approval_strategy/ufwmpg_ati'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_50_output_all_dirs_phash_approval_strategy/wzwvzv_ooo'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_50_output_all_dirs_phash_approval_strategy/tpfibt_cjp'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_50_output_all_dirs_phash_approval_strategy/pwlueg_uxz'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_50_output_all_dirs_phash_approval_strategy/jgywnx_rfq'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_50_output_all_dirs_phash_approval_strategy/xtlxph_abk'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_50_output_all_dirs_phash_approval_strategy/eqcnrd_cbn'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_50_output_all_dirs_phash_approval_strategy/whsuyw_qcp'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_50_output_all_dirs_phash_approval_strategy/jlsjyc_egl'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_50_output_all_dirs_phash_approval_strategy/lxwqhv_pgz'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_50_output_all_dirs_phash_approval_strategy/cyqohz_oux'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_50_output_all_dirs_phash_approval_strategy/sktpkr_bhg'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_50_output_all_dirs_phash_approval_strategy/rjgctw_crb'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_50_output_all_dirs_phash_approval_strategy/yrhkqu_wbb'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_50_output_all_dirs_phash_approval_strategy/sosjvp_quh'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_50_output_all_dirs_phash_approval_strategy/nhwrqw_vyj'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_50_output_all_dirs_phash_approval_strategy/vxcarn_lab'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_50_output_all_dirs_phash_approval_strategy/zirldl_szk'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_50_output_all_dirs_phash_approval_strategy/txxahm_ahe'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_50_output_all_dirs_phash_approval_strategy/iyyoht_xed'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_50_output_all_dirs_phash_approval_strategy/jautph_pvi'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_50_output_all_dirs_phash_approval_strategy/vvywdg_rvc'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_50_output_all_dirs_phash_approval_strategy/djwahz_ppw'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_50_output_all_dirs_phash_approval_strategy/afsikc_cng'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_50_output_all_dirs_phash_approval_strategy/hgkxep_lla'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_50_output_all_dirs_phash_approval_strategy/ubqley_kbe'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_50_output_all_dirs_phash_approval_strategy/cakavo_emg'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_50_output_all_dirs_phash_approval_strategy/mbgcel_hpj'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_50_output_all_dirs_phash_approval_strategy/kaitxy_koc'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_50_output_all_dirs_phash_approval_strategy/yecmvl_liu'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_50_output_all_dirs_phash_approval_strategy/pbfssh_xcm'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_50_output_all_dirs_phash_approval_strategy/eupjay_oii'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_50_output_all_dirs_phash_approval_strategy/wayvbl_lga'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_50_output_all_dirs_phash_approval_strategy/xiietr_vdb'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_50_output_all_dirs_phash_approval_strategy/uhrpei_qqf'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_50_output_all_dirs_phash_approval_strategy/kjajup_wss'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_50_output_all_dirs_phash_approval_strategy/gddyar_bhp'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_50_output_all_dirs_phash_approval_strategy/yrazjn_aey'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_46_everything_except_local_videos_pdfs'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_52_new_reference_pdfs_pdfs'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_53_only_long_videos_pdfs'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_50_python_objects_all_dirs_phash_approval_strategy'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_44_everything_except_local_videos__pdfs'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_51_to_del/pidfog_fsa_ptl'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_51_to_del/sgmaal_zgd_vhv'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_51_to_del/jrixdt_xgr_lpd'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_51_to_del/mfewuh_qkh_iwo'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_51_to_del/erhbqn_akx_ezk'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_51_to_del/mlvdvr_rhl_dja'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_51_to_del/xtlxph_abk_dfi'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_51_to_del/zgpqgn_qjr_pfm'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_51_to_del/cncwmr_ivc_ljm'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_51_to_del/sosjvp_quh_jss'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_51_to_del/xdrrpx_fow_zrv'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_51_to_del/asycxh_rfq_unl'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_51_to_del/dtwoem_nzp_tzy'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_51_to_del/cftulg_fdx_osn'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_51_to_del/cyqohz_oux_gbt'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_51_to_del/tabwoi_utc_wdf'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_51_to_del/rskdzi_lay_fbj'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_51_to_del/rzcsvv_fov_qji'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_51_to_del/qzxibg_vyv_wuf'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_51_to_del/ijifjf_rmq_zpm'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_51_to_del/hripxz_ueh_diz'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_51_to_del/iqntxc_lro_gls'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_51_to_del/oyxwwk_qfb_god'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_51_to_del/iyyoht_xed_nti'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_51_to_del/ruweka_emf_nny'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_51_to_del/znavfo_tfc_jqe'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_51_to_del/yysaqx_fmp_kus'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_51_to_del/zrkmxn_had_xjk'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_51_to_del/zirldl_szk_ytj'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_51_to_del/xfzngr_gja_hzo'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_51_to_del/hydixc_tri_tao'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_51_to_del/czeswe_nns_fah'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_51_to_del/dxeqwb_ufq_uij'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_51_to_del/sdcniw_khg_xjc'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_51_to_del/msskhv_dmg_sfv'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_51_to_del/hhboxg_lxm_gep'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_51_to_del/bsjwsj_suf_ziu'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_51_to_del/srmqde_fys_yil'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_43_pdfs'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_51_to_del_pdfs'),
#  PosixPath('/home/vedant/Desktop/glimpsify/most_info_frame_extractor/video2pdf/archives/data_archive_49_phash_results_all_dirs_v2')]

# %%
for i in to_delete:
    shutil.rmtree(i)
